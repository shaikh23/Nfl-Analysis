# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup as bs
from bs4 import Comment as Comment
import numpy as np
import pandas as pd
import pymongo

#for pro-football-reference.com
url = 'https://www.pro-football-reference.com/years/2019/passing.htm'
user_agent = {'User-agent':'Mozilla/5.0'}

r = requests.get(url, user_agent)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html data-version="klecko-" data-root="/home/pfr/build" itemscope itemtype="https://schema.org/WebSite" lang="en" class="no-js" >
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />
#     <link rel="dns-prefetch" href="https://d2p3bygnnzw9w3.cloudfront.net/req/202007101" />
#
# <!-- no:cookie fast load the css.           -->
# <script>function gup(n) {n = n.replace(/[\[]/, '\\[').replace(/[\]]/, '\\]'); var r = new RegExp('[\\?&]'+n+'=([^&#]*)'); var re = r.exec(location.search);   return re === null?'':decodeURIComponent(re[1].replace(/\+/g,' '));}; document.srdev = gup('srdev')</script>
# <link rel="preconnect" href="https://d2p3bygnnzw9w3.cloudfront.net" crossorigin>
#
# ...

# %%
client = pymongo.MongoClient('localhost', 27017)
db = client['sportsio']
coll = db['heights']

# %%
soup = bs(r.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/pfr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport">
#    <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/202007101" rel="dns-prefetch"/>
#    <!-- no:cookie fast load the css.           -->
#    <script>
#     function gup(n) {n = n.replace(/[\[]/, '\\[').replace(/[\]]/, '\\]'); var r = new RegExp('[\\?&]'+n+'=([^&#]*)'); var re = r.exec(location.search);   return re === null?'':decodeURIComponent(re[1].replace(/\+/g,' '));}; document.srdev = gup('srdev')
#    </script>
#    <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
#    <style>
# ...

# %%
# #for sportsdata.io using api
# client = pymongo.MongoClient('localhost', 27017)
# db = client['sportsio']
# coll = db['heights']

# %%
api_url = 'https://api.sportsdata.io/v3/nfl/scores/json/Players?key=933b952a356a49d28f6fa546c5e7f3d5'
r2 = requests.get(api_url)
r2.status_code

r2
# Out:
# <Response [200]>

# %% [raw]
# return r2.json(
# soup = BeautifulSoup(r2.text, 'html.parser')
# print(soup.prettify())

# %%
h_weigh = pd.DataFrame.from_dict(r2)
h_weigh.head()
# Out:
#                                                    0
# 0  b'[{"PlayerID":21939,"Team":"LAC","Number":32,...
# 1  b'\'11\\"","Weight":201,"BirthDate":"1997-09-1...
# 2  b',"PositionCategory":"DEF","Name":"Alohi Gilm...
# 3  b'toUrl":"https:\\/\\/s3-us-west-2.amazonaws.c...
# 4  b'Opponent":"DAL","UpcomingGameWeek":1,"ShortN...

# %%
import data/run_py
# Out:
#   File "<ipython-input-13-79db99a443d5>", line 1
#     import data/run_py
#                ^
# SyntaxError: invalid syntax
